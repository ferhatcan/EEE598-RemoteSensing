# %%
import os

from ddpm import run_all, run_inference
from utils import plot_images
from PIL import Image
import numpy as np
import torch
import torchvision
import torchvision.transforms as T
from model import UNet_Classic
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
run_all()
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
#     <div>
#       <progress value='181' class='' max='100000' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.18% [181/100000 11:46:33&lt;6494:21:21 MSE=0.00031]
#     </div>
# 08:31:53 - INFO: Starting epoch 0:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
# ...

# %%
images, sampled_images, ema_sampled_images, gts = run_inference(r"models\UNet_classic_new_data_latest-181")

# %%
images_comb = torch.cat([torch.cat([i for i in images.cpu()], dim=-1),], dim=-2).permute(1, 2, 0).cpu()
ema_sampled_comb = torch.cat([torch.cat([i for i in ema_sampled_images.cpu()], dim=-1),], dim=-2).permute(1, 2, 0).cpu()

all_combined = torch.cat([images_comb, ema_sampled_comb], dim=0)

plt.imshow(all_combined)

im = Image.fromarray(all_combined.numpy())
im.save("images/classic_result.png")

# %%
model_cpkt_path = r"models\UNet_classic_new_data_latest-181"
device = 'cpu'

im_path = r'D:\Dataset\NH-HAZE\12_hazy.png'
im = Image.open(im_path).convert('RGB')
im_np = np.array(im)
val_transforms = torchvision.transforms.Compose([
    T.CenterCrop(1024),
    T.Resize(128),
    T.ToTensor(),
    T.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5)),
])

im_torch = val_transforms(im).to(device).unsqueeze(0)
model = UNet_Classic(3, 3).to(device)
model.load_state_dict(torch.load(os.path.join(model_cpkt_path, "ckpt.pt")))

with torch.no_grad():
    dehaze_im = model(im_torch)
dehaze_im = (dehaze_im.clamp(-1, 1) + 1) / 2
dehaze_im = (dehaze_im * 255).type(torch.uint8)
plot_images(dehaze_im)

# %%
im_torch_cpu = ((im_torch.squeeze().detach().cpu() + 1) / 2) * 255
im_path_gt = r'D:\Dataset\NH-HAZE\12_GT.png'
im_gt = Image.open(im_path_gt).convert('RGB')
im_gt_torch = val_transforms(im_gt)
im_gt_torch = ((im_gt_torch.squeeze().detach().cpu() + 1) / 2) * 255

gt_combined = torch.cat([im_torch_cpu.type(torch.uint8), dehaze_im.squeeze(), im_gt_torch.type(torch.uint8)], dim=-1).permute(1, 2, 0)

plt.imshow(gt_combined)

im = Image.fromarray(gt_combined.numpy())
im.save("images/classic_result_ntire.png")

# %%
gt_combined.shape
# Out:
# torch.Size([128, 256, 3])
